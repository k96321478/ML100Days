# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    mse= MSE= sum((y - yp)**2) / len(y)
    return mse
MSE =  mean_squared_error(y, y_hat)
print("The Mean squared erroris %.3f" % (MSE))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 21
#      19     mse= MSE= sum((y - yp)**2) / len(y)
#      20     return mse
# ---> 21 MSE =  mean_squared_error(y, y_hat)
#      22 print("The Mean squared erroris %.3f" % (MSE))
#
# NameError: name 'y' is not defined

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 270.483
# The Mean absolute error is 13.187

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# 我選的基於脈搏波波形特徵預測冠狀動脈硬化
#
# 1.  透過AI進行第一步的PWV判讀或是可能性預測，可以在冠狀動脈的早期做診斷甚至達到預防的效果
# 2.  巨量移動科技有限公司
# 3.  200~500筆病患之ECG& PWV資料、臨床資料，包含圖檔以及CSV檔案
# 4.  1.冠狀動脈硬化判讀以即早預測AI模型。
#     2.Precision> 90%，召回率> 90%
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 如何在最短的時間內接到最多的客人，進一步提升業績及載客量。
# 2. 可能是蒐集各個客人上下課的地方來進行預測，達到最短路線。
# 3. 上下車的經緯度、客人年齡、到達載客點的時間、行車路程多長、總共耗時。
# 4. 每個司機接到客人的平均時間有無減少，平均的業績及載客量有無提升，模型部屬後預測的下車地點是否正確。
